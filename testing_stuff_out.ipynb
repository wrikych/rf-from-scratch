# %%
import numpy as np 
import pandas as pd 
import random 
from helper_functions import * 
import warnings
from pandas.errors import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action="ignore", category=FutureWarning)

main = pd.read_csv('train.csv')
main.Transported.value_counts()


sample_percentage = 0.1
df = main.sample(frac=sample_percentage)

app1, app2 = data_preprocess(df)
# Out:
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'D' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'Trip'] = assign_trip(row['HomePlanet'], row['Destination'])

# %%
tree_ls = random_forest(app1, n_estimators=10)
# Out:
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["classification"] = df.apply(classify_example, axis=1, args=(tree,))
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["classification_correct"] = df["classification"] == df["label"]
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:342: SettingWithCopyWarning:
# ...

# %%
acc = model_testing(app1, trees=tree_ls)

# %%
acc
# Out:
# 0.8032220943613348

# %%
app1_train, app1_test = train_test_split(app1, test_size=0.2)

# %%
tree_train = random_forest(app1_train, n_estimators=10)
# Out:
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["classification"] = df.apply(classify_example, axis=1, args=(tree,))
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["classification_correct"] = df["classification"] == df["label"]
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:342: SettingWithCopyWarning:
# ...

# %%
acc2 = model_testing(app1_test, trees=tree_train)

# %%
acc2
# Out:
# 0.5

# %%
tree_train
# Out:
# [{'Trip = A': [{'Spa <= 80.0': [{'FoodCourt <= 1307.0': [{'RoomService <= 887.0': [{'RoomService <= 711.0': [True,
#            False]},
#          True]},
#        False]},
#      {'Spa <= 721.0': [True, False]}]},
#    {'ShoppingMall <= 201.0': [{'RoomService <= 866.0': [True,
#        {'label = True': [False, True]}]},
#      {'Trip = C': [{'ShoppingMall <= 687.0': [False,
#          {'FoodCourt <= 2.0': [True, False]}]},
#        {'VRDeck <= 142.0': [{'ShoppingMall <= 206.0': [False, True]},
#          False]}]}]}]},
#  {'Trip = E': [{'Age <= 46.0': [True, {'CryoSleep = True': [True, False]}]},
#    {'Trip = H': [True,
#      {'ShoppingMall <= 289.0': [True,
#        {'Spa <= 90.0': [{'ShoppingMall <= 323.0': [False, True]}, True]}]}]}]},
#  {'RoomService <= 1413.0': [{'ShoppingMall <= 677.0': [{'Spa <= 1267.0': [{'VIP = False': [True,
#          {'VRDeck <= 13.0': [False, True]}]},
#        True]},
#      {'VRDeck <= 18.0': [{'Spa <= 12.0': [{'Spa <= 0.0': [True, False]},
# ...

# %%
scores = cross_val(app1, k=5, estimators=10)
# Out:
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["classification"] = df.apply(classify_example, axis=1, args=(tree,))
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["classification_correct"] = df["classification"] == df["label"]
# c:\Users\wriky\final_project_files\rf_from_scratch\helper_functions.py:342: SettingWithCopyWarning:
# ...
